# %% [markdown]
# <a href="https://colab.research.google.com/github/Julian-Banks/EEE4022S_BNKJUL001_Thesis/blob/main/PythonWorkspace/EMSv1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Version Notes**
#
# # **v1.0**
#
# **Added:**
# * AC and DC load
# * Wind Gen
# * changed obs space to hold new loads
# * re wrote standby and purchase functions
#
# **To DO**
# * thinking that maybe I should change obs space back to what it was cause I dont actully need to know individual loads and gens!!!!
# * Add in rectifier & inverter power tracking
# * battery charging rates
#
#
# # **v0.3**
# **Added:**
# * loadshedding
# * New reward structure
# * added Vec_env
# * added eval callbacks to validate training
# * added in logging
#
# **Parameters:**
# * Added in loadshedding forecast
#
# **To do:**
# * find out about battery charging rates  & impliment
# * Find out if I need to normalise
# * Try dqn
# * Find out how the bounds for the obs_space box effect things
# * Try play with DummyVec wrapper (didnt work in last version)
#
# # **v0.2_1**
# **Added:**
# *  Monitor wrapper
# *  DummyVec wrapper
# *  Wand (weights and bais) enabled
#
# **Parameters:**
# * lowered to 3 predictions
#
# **To do:**
# * Try to use hyperparameter Optimisation - decided Im only going to do on the final version
# * Try normalise
# * Try differnet models
# * Find out how the bounds for the obs_space box effect things
#
# # **v0.2**
# **Added:**
# *  simplified load_forecast and gen_forecast to be power_bal_forecasts.
# *  combined current_load and current_gen to also show current_power_balance
# *  added proper evaluate call
#
# **Parameters:**
# * No changes
#
# **Results:**
# * 5% savings on PPO deterministic = true
# * 4.3% savings on PPO determnistic = false
#
# **To do:**
# * Try to use hyperparameter Optimisation
# * Try normalise
# * Try differnet models
# * Try see if discount rate can be tweaked - at good level.
# * Find out how the bounds for the obs_space box effect things
#
# # **v0.1**
# **Added:**
# * added real loads, gen, tou_id's
#
# **Parameters:**
# * training episode = 6000 timesteps
# * testing episode  = 2760 timesteps
# * bat_threshold = 100
# * bat_cap = 500
# * battery_level at reset = bat_cap/2
# * num_preds = 24
# * Trained PPO for 1.65mil timesteps
# * Trained A2C for 1.2 mil timesteps
#
# **Results:**
# * PP0 - 3.7% improvement from standby mode Deterministic = False
# * PPO - 6.1% Deterministic =  True
# * A2C  - -0.3% improvement. And the models after this got worse as training progressed!
# **To do:**
# * Try lower num_preds
# * Try to use hyperparameter Optimisation
# * Try normalise
# * Try differnet models
# * Try see if discount rate can be tweaked

# %%
# %%capture
#install dependancies
# !pip install gymnasium
# !pip install stable_baselines3[extra]
# !pip install wandb
# %load_ext tensorboard

#clone repository
! git clone https://github.com/Julian-Banks/EEE4022S_BNKJUL001_Thesis

#to update the rep
# %cd /content/EEE4022S_BNKJUL001_Thesis
! git pull
#import needed libarys
import gymnasium as gym
import numpy as np
import pandas as pd
from gymnasium import spaces
import datetime
from stable_baselines3 import PPO, A2C, DQN
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecVideoRecorder
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from gym.wrappers import FlattenObservation


from google.colab import drive
import os
import wandb
from wandb.integration.sb3 import WandbCallback
from gymnasium.envs.registration import register



#mount the drive
drive.mount('/content/drive')
#define paths to logs and model saves
model_type = "PPO_2"
version    = "EMSv1_0"
model_dir = f"/content/drive/MyDrive/Colab Notebooks/{version}/models/{model_type}/"
log_dir   = f"/content/drive/MyDrive/Colab Notebooks/{version}/models/{model_type}logs/"
animation_dir = f"/content/drive/MyDrive/Colab Notebooks/{version}/models/{model_type}/animation"

#make the appropriate directory if it does not exist
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(animation_dir):
    os.makedirs(animation_dir)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Define our environment class!!**

# %%
class EMSv1_0(gym.Env):
    """Custom Environment that follows gym interface."""

    metadata = {"render_modes": ["human","rgb_array"], "render_fps": 30}

    def __init__(self,bat_threshold = 0.1, bat_cap = 1, actual_load = "none", actual_gen = "none", purchase_price = [1,1,1,1,1,1,1,1,2,2,2,2] , episode_len = 8760,num_preds = 24,render_mode = "rgb_array", load_shedding = "none", wandb_log = False,train_log = True):

        super(EMSv1_0, self).__init__()
        #define render_mode
        self.render_mode = render_mode
        #define wandb
        self.wandb_log = wandb_log
        self.train_log = train_log
        #define time frame
        self.current_step = 0
        self.final_step = int(episode_len)-num_preds-2 #one years worth of steps

        #Might make a function for these
        #fill all of the actual loads NB!!! is just random for now NB!!! is normalised 0-1
        if isinstance(actual_load,str) :
            self.actual_load = np.random.rand(self.final_step+num_preds+1,2).astype(np.float32) #will load from a file or something
        else:
           self.actual_load  = actual_load[:episode_len,:]

        #fill all of the actual generation steps.
        if isinstance(actual_gen,str):
            self.actual_gen  = np.random.rand(self.final_step+num_preds+1,2).astype(np.float32) #will load from file or something
        else:
            self.actual_gen  = actual_gen[:episode_len,:]

        #Fill the loadShedding indicator
        if isinstance(load_shedding,str):
            num_shedding   = np.random.randint(int(0.02*episode_len), int(0.05*episode_len))
            load_shed      = np.array([1]*num_shedding + [0]*(episode_len - num_shedding))
            np.random.shuffle(load_shed)
            self.load_shed = load_shed
        else:
            self.load_shed = load_shedding[:episode_len]

        #define vars for render
        self.off_peak_purchases = 0
        self.peak_purchases     = 0
        self.standard_purchases = 0
        self.off_peak_num       = 0
        self.peak_num           = 0
        self.standard           = 0
        self.unmet_load_total   = 0
        self.frames = []

        #Define a var for unmet load no that there is loadshedding
        self.step_unmet_load = 0

        #define the purchase price for every step of the year
        purchase_price = np.array(purchase_price).astype(np.float32)
        repetitions    = (self.final_step+num_preds+1) // len(purchase_price)
        remainder      = (self.final_step+num_preds+1) % len(purchase_price)
        self.purchase_price =np.concatenate([purchase_price]*repetitions+[purchase_price[:remainder]])#need to read in from somewhere

        #define var for storing the excess gen
        self.excess_gen = 0
        #define a var for determine amount purchased per step (dont want to make it total as this will incure growing penalties for the Agent if used in reward structure)
        self.step_purchased = 0
        self.purchased_total = 0
        #define the battery max capacity
        self.bat_cap = bat_cap
        #define the battery low threshold
        self.bat_threshold = np.float32(bat_threshold)
        #define default action
        self.default_action = 0
        #define actions and observations space
        n_actions = 2 # keeping it simple

        self.num_preds = num_preds # day ahead predictions
        #define how many different loads and generators there are
        self.num_loads = self.actual_load.shape[1]
        #define the size of the action space
        self.action_space = spaces.Discrete(n_actions)
        # Dict space to store all the different things
        self.observation_space = spaces.Dict({
                "power_bal_forecast": gym.spaces.Box(low=-np.inf, high=np.inf, shape=(1,num_preds,self.num_loads), dtype=np.float32),
                "price_forecast": gym.spaces.Box(low=0, high=np.inf, shape=(1,num_preds+1), dtype=np.float32),
                "island_forecast": gym.spaces.Box(low=0, high=1, shape=(1,num_preds+1), dtype=np.float32),
                "bat_level": gym.spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32),
                "current_power_bal": gym.spaces.Box(low=-np.inf, high=np.inf, shape=(1,self.num_loads), dtype=np.float32),
                })

    def step(self, action):

        #update the current state with the action (needs to be done before current_step is inc since we want to apply the action to the previous step to get the current state)
        self.update_state(action)
        #Calculate reward from the action
        reward = self.calc_reward()
        #inc time step into Future
        self.current_step += 1
        #get next observation (for next time step)
        observation = self.get_obs()
        #Set terminated to False since there are no failure states
        self.terminated = False
        #Check if timelimit reached
        self.truncated = False if self.current_step<self.final_step else True
        #Wand log, if its set to true(so that it only gets run when wandb is initialised)
        if self.wandb_log == True:
            #doing this for training logging
            if self.train_log == True:
                if self.current_step == self.final_step:
                    self.wandb_logger()
            else:
                self.wandb_logger()
        #dont know what to put into info for now
        info = {}
        return observation, reward, self.terminated, self.truncated, info

    def reset(self, seed=None, options=None):
        super().reset(seed = seed, options=options)

        self.current_step = 0
        self.terminated = False
        self.truncated = False
        #reset the state
        self.battery_level = self.bat_cap/2
        self.excess_gen = 0
        self.step_purchased = 0
        self.step_unmet_load = 0
        self.off_peak_purchases = 0
        self.off_peak_num       = 0
        self.peak_purchases     = 0
        self.peak_num           = 0
        self.standard_purchases = 0
        self.standard_num       = 0
        self.unmet_load_total   = 0
        self.purchased_total  = 0
        self.purchase_count = 0
        self.standby_count= 0
        #get the first observation
        observation = self.get_obs()
        #Still don't know what to do with info
        info = {}
        return observation, info



    def render(self, mode='rgb_array', save_path=None):

        plt.clf()
        values = [self.off_peak_purchases, self.standard_purchases, self.purchase_price[self.peak_purchases]]
        colors = ['green', 'orange','red']
        labels = ['Off Peak', 'Standard', 'Peak']
        plt.xlim(0,1.6)
        plt.ylim(0,100)
        plt.bar(list(range(3)),values, color=colors, tick_label=labels)
        self.frames.append(plt.gcf().canvas.tostring_rgb())
        plt.pause(0.000001)

    def wandb_logger(self):
        train_log_dict={
                    "Excess Generation" :self.excess_gen,
                    "Unmet Load"        :self.unmet_load_total,
                    "Off-Peak Purchases":self.off_peak_purchases,
                    "Standard Purchases":self.standard_purchases,
                    "Peak Purchases": self.peak_purchases,
                    "Num Off-Peak Purchases":self.off_peak_num,
                    "Num Standard Purchases":self.standard_num,
                    "Num Peak Purchases": self.peak_num,
                    "Num Standby Actions": self.standby_count,
                    "Num Purchase Count":self.purchase_count

                  }
        eval_log_dict={
                    "battery_level"     :self.battery_level,
                    "AC load"           :self.actual_load[self.current_step,0],
                    "DC load"           :self.actual_load[self.current_step,1],
                    "PV generation"     :self.actual_gen[self.current_step,0],
                    "Wind generation"   :self.actual_gen[self.current_step,1],
                    "Excess Generation" :self.excess_gen,
                    "Unmet Load"        :self.unmet_load_total,
                    "LoadShedding"      :self.load_shed[self.current_step],
                    "Current_step"      :self.current_step,
                    "Off-Peak Purchases":self.off_peak_purchases,
                    "Standard Purchases":self.standard_purchases,
                    "Peak Purchases": self.peak_purchases,
                    "Num Off-Peak Purchases":self.off_peak_num,
                    "Num Standard Purchases":self.standard_num,
                    "Num Peak Purchases": self.peak_num,
                    "Num Standby Actions": self.standby_count,
                    "Num Purchase Count":self.purchase_count

                  }

        if self.train_log:
            wandb.log(train_log_dict)
        else:
            wandb.log(eval_log_dict)


        '''
        plt.clf()
        values = [self.off_peak_purchases, self.standard_purchases, self.purchase_price[self.peak_purchases]]
        colors = ['green', 'orange','red']
        labels = ['Off Peak', 'Standard', 'Peak']
        plt.xlim(0,1.6)
        plt.ylim(0,100)
        plt.bar(list(range(3)),values, color=colors, tick_label=labels)
        wandb.log({"Num Purchases per Tariff rate": plt})'''

    def close(self):
        #don't think i need this for my application
        pass

    def update_state(self, action):
        #reset step vars
        self.step_purchased = 0
        self.step_unmet_load = 0
        #Update current state with actions
        if action == 0: #do nothing action
            self.standby()
        elif action == 1: #buy from Grid
            self.purchase()
        else:  #error case
            raise ValueError(
                f"Received invalid action = {action} which is not part of the action space."
            )
        self.unmet_load_total += self.step_unmet_load
        self.purchased_total += self.step_purchased
        self.tou_purchase_inc()

    def calc_reward(self):
        #Calculate reward based on the state
        reward = -self.step_purchased*self.purchase_price[self.current_step] - self.step_unmet_load*10

        return reward

    def get_obs(self):
        #Fill the observation space with the next observation

        #Get Forecasts Will probaly write a function for this? idk maybe a schlep to return all the info
        load_forecast  = np.array( [self.actual_load[self.current_step+1: self.current_step + self.num_preds+1,:]] , dtype = np.float32) #will load from a file or something
        gen_forecast   = np.array( [self.actual_gen[self.current_step+1: self.current_step + self.num_preds+1,:]] , dtype = np.float32) #will load from a file or something
        #calculate the power forecast
        power_bal_forecast = gen_forecast-load_forecast
        #get the prices for the current frame and the next 24 hours. Maybe will cut this down since that seems like a lot of info
        price_forecast = np.array( [self.purchase_price[self.current_step:self.current_step+self.num_preds+1]] , dtype = np.float32)
        #Just for readibility of the dict object
        bat_level      = np.array([self.battery_level] , dtype= np.float32)
        #island forecasst, same as tou forecast
        island_forecast =np.array( [self.load_shed[self.current_step:self.current_step+self.num_preds+1]] , dtype = np.float32)

        #calculate the current power balance
        current_load   = np.array([self.actual_load[self.current_step,:]], dtype = np.float32)
        current_gen    = np.array([self.actual_gen[self.current_step,:]], dtype  = np.float32)
        current_power_bal = current_gen - current_load



        obs = dict({
                "bat_level":      bat_level,
                "current_power_bal" :   current_power_bal,
                "island_forecast": island_forecast,
                "power_bal_forecast":  power_bal_forecast,
                "price_forecast": price_forecast,
        })
        return obs

    def AC_bus(self):
        #fill out info on the ac
        ac_gen = self.actual_gen[self.current_step, 0]
        ac_load = self.actual_load[self.current_step,0]
        ac_power_bal = ac_gen - ac_load
        #check if there is load shedding or not
        avail_grid = not self.load_shed[self.current_step]
        #ac_diesel = Don't know what yet but I do want to use it for something.
        #return relevant values
        return ac_power_bal,avail_grid

    def DC_bus(self):
        #fill in info for DC_bus
        dc_gen       = self.actual_gen[self.current_step,1]
        dc_load      = self.actual_load[self.current_step,1]
        dc_power_bal = dc_gen - dc_load
        #Haven't imposed limits here but I don't think I need to. Must check.
        avail_bat  = self.battery_level - self.bat_threshold
        avail_stor = self.bat_cap       - self.battery_level
        return dc_power_bal, avail_bat, avail_stor

    def standby(self):
        self.standby_count+=1
        #fetch info from grids
        ac_power_bal, avail_grid = self.AC_bus()
        dc_power_bal, avail_bat, avail_stor = self.DC_bus()

        #calculate the immediate power_bal
        grid_power_bal = ac_power_bal + dc_power_bal
        #determine the flow of power:
        if grid_power_bal > 0 :
            #increments the battery level by the minimium between avail_stor and grid_power_bal ( always keeps it in range)
            self.battery_level += min(avail_stor, grid_power_bal)
            #increments excess gen by the max ( if grid_power_bal - avail_stor is negative, there was no excess and it will add 0, else it will add the excess that wasn't stored)
            self.excess_gen += max((grid_power_bal - avail_stor), 0)
        else:
            #there is a shortage of power, see if we can take it from the battery.
            # flipping the sign of the grid power balance, bacause it will be negative if we get here
            self.battery_level -= min(avail_bat, -grid_power_bal)
            #check if we are islanded and buy elec if we arent
            if avail_grid:
                #if the grid is available (make power bal positive, minus the amount we drew from batter and take the max between that and zero)
                self.step_purchased = max(-grid_power_bal- avail_bat, 0)
            else:
                #if not available add to the step un_met_load.
                self.step_unmet_load = max(-grid_power_bal- avail_bat, 0)

    def purchase(self):
        self.purchase_count +=1
        #fetch info from grids
        ac_power_bal, avail_grid = self.AC_bus()
        dc_power_bal, avail_bat, avail_stor = self.DC_bus()

        if avail_grid:
            grid_power_bal = ac_power_bal+dc_power_bal
            #if we are grid connected purchase the max between the amount needed elec and 0
            self.step_purchased = max(-grid_power_bal + avail_stor,0)
            #set Battery to full
            self.battery_level = self.bat_cap
            #calculate and add the excess electricity generated.
            self.excess_gen += max((grid_power_bal - avail_stor), 0)
        else:
            #if the grid is not available then we can't purchase and standby can handle power flow ect
            self.standby()

    def tou_purchase_inc(self):
        if self.step_purchased != 0:
            if self.purchase_price[self.current_step] == 1:
                self.off_peak_purchases += self.step_purchased
                self.off_peak_num       += 1
            elif self.purchase_price[self.current_step] == 2:
                self.standard_purchases += self.step_purchased
                self.standard_num       += 1
            elif self.purchase_price[self.current_step] == 3:
                self.peak_purchases += self.step_purchased
                self.peak_num += 1



#define a pointer (kinda, don't actually know what its called) a
EMS = EMSv1_0

# Register environment so I can use make_vec_env
register(
# unique identifier for the env `name-version`
id=f"{version}",
# path to the class for creating the env
# Note: entry_point also accept a class as input (and not only a string)
entry_point= EMS(),

)

#Check the environment with stable_baselines3 check_env.
from stable_baselines3.common.env_checker import check_env
env = EMS()
check_env(env,warn = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment EMSv1_0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/env_checker.py:244: UserWarning: Your observation current_power_bal has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/env_checker.py:244: UserWarning: Your observation island_forecast has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/env_checker.py:30: UserWarning: It seems that your observation power_bal_forecast is an image but its `dtype` is (float32) whereas it has to be `np.uint8`. If your observation is not an image, we recommend you to flatten the observation to have only a 1D vector
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/env_checker.py:38: UserWarning: It seems that your observation space power_bal_forecast is an image but the upper and lower bounds are not in [0, 255]. Because the CNN policy normalize automatically the observation you may encounter issue if the values are not in that range.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/env_checker.py:51: UserWarning: The minimal resolution for an image is 36x36 for the default `CnnPolicy`. You might need to use a custom features extractor cf. https://stable-baselines3.readthedocs.io/en/master/guide/custom_policy.html
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/env_checker.py:244: UserWarning: Your observation price_forecast has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(

# %% [markdown]
# **Load in the data for our specific microgrid.**

# %%
#need to import data from Github
path_data = "/content/EEE4022S_BNKJUL001_Thesis/PythonWorkspace/dataClean.csv"
data = pd.read_csv(path_data)

path_pv_gen = "/content/EEE4022S_BNKJUL001_Thesis/Generation/BNKJUL001_Thesis_solarGen500kWHomer.csv"
data_pv_gen = pd.read_csv(path_pv_gen)

path_wind_gen = "/content/EEE4022S_BNKJUL001_Thesis/Generation/BNKJUL001_Thesis_Wind500kGenHomer.csv"
data_wind_gen = pd.read_csv(path_wind_gen)

#Not actually using this rn but will be soon :)
path_shedding = "/content/EEE4022S_BNKJUL001_Thesis/MatlabWorkSpace/loadShedding2022.csv"
data_shedding = pd.read_csv(path_shedding)
load_shedding = data_shedding['LoadShedding'].values.astype(np.float32)

wind_gen = data_wind_gen['Wind_Out'].values.astype(np.float32)
PV_gen = data_pv_gen['PV_Out'].values.astype(np.float32)
actual_gen = np.column_stack((wind_gen, PV_gen))
#read in ac and DC load
AC_load = data['AC'].values.astype(np.float32)
DC_load = data['DC'].values.astype(np.float32)
#stack em together for the input :)
actual_load = np.column_stack((AC_load, DC_load))
purchase_price = data['tou_id'].values.astype(np.float32)


#define the base environment
base_env = EMS(episode_len = 6000, actual_load = actual_load, actual_gen = actual_gen, bat_threshold = 100, bat_cap = 500, purchase_price = purchase_price,num_preds = 3)
#going to print out a bunch of things to test the different spaces.
obs,_    = base_env.reset()
print(f"The reset observation space looks like: {obs}")
battery_level = obs['bat_level']
print(f"Battery level is: {battery_level[0]}kWh")
current_power_bal = obs['current_power_bal']
print(f"Current AC Power Balance {current_power_bal[0,0]}, Current DC Power Balance{current_power_bal[0,1]}")
power_forecast = obs['power_bal_forecast']
print(f"Forecasted AC power 1 hour ahead: {power_forecast[0,0,0]}. Forecasted DC power 1 hour ahead: {power_forecast[0,0,1]}")
print(f"Forecasted AC power 2 hour ahead: {power_forecast[0,1,0]}. Forecasted DC power 2 hour ahead: {power_forecast[0,1,1]}")
print(f"Forecasted AC power 3 hour ahead: {power_forecast[0,2,0]}. Forecasted DC power 3 hour ahead: {power_forecast[0,2,1]}")
print(f"The reward we recieved was {reward}")
print(f"_________________________________________________________________________________________________________________")
print(f"")


action_standby = 0
obs,reward,terminated,truncated,info = base_env.step(action_standby)
print(f"After action {action_standby}: " )
battery_level = obs['bat_level']
print(f"Battery level is: {battery_level[0]}kWh")
current_power_bal = obs['current_power_bal']
print(f"Current AC Power Balance {current_power_bal[0,0]}, Current DC Power Balance{current_power_bal[0,1]}")
power_forecast = obs['power_bal_forecast']
print(f"Forecasted AC power 1 hour ahead: {power_forecast[0,0,0]}. Forecasted DC power 1 hour ahead: {power_forecast[0,0,1]}")
print(f"Forecasted AC power 2 hour ahead: {power_forecast[0,1,0]}. Forecasted DC power 2 hour ahead: {power_forecast[0,1,1]}")
print(f"Forecasted AC power 3 hour ahead: {power_forecast[0,2,0]}. Forecasted DC power 3 hour ahead: {power_forecast[0,2,1]}")
print(f"The reward we recieved was {reward}")
print(f"_________________________________________________________________________________________________________________")
print(f"")
action_standby = 0
obs,reward,terminated,truncated,info = base_env.step(action_standby)
print(f"After action {action_standby}: " )
battery_level = obs['bat_level']
print(f"Battery level is: {battery_level[0]}kWh")
current_power_bal = obs['current_power_bal']
print(f"Current AC Power Balance {current_power_bal[0,0]}, Current DC Power Balance{current_power_bal[0,1]}")
power_forecast = obs['power_bal_forecast']
print(f"Forecasted AC power 1 hour ahead: {power_forecast[0,0,0]}. Forecasted DC power 1 hour ahead: {power_forecast[0,0,1]}")
print(f"Forecasted AC power 2 hour ahead: {power_forecast[0,1,0]}. Forecasted DC power 2 hour ahead: {power_forecast[0,1,1]}")
print(f"Forecasted AC power 3 hour ahead: {power_forecast[0,2,0]}. Forecasted DC power 3 hour ahead: {power_forecast[0,2,1]}")
print(f"The reward we recieved was {reward}")
print(f"_________________________________________________________________________________________________________________")
print(f"")
obs,reward,terminated,truncated,info = base_env.step(1)
print(f"After action {1} : " )
battery_level = obs['bat_level']
print(f"Battery level is: {battery_level[0]}kWh")
current_power_bal = obs['current_power_bal']
print(f"Current AC Power Balance {current_power_bal[0,0]}, Current DC Power Balance{current_power_bal[0,1]}")
power_forecast = obs['power_bal_forecast']
print(f"Forecasted AC power 1 hour ahead: {power_forecast[0,0,0]}. Forecasted DC power 1 hour ahead: {power_forecast[0,0,1]}")
print(f"Forecasted AC power 2 hour ahead: {power_forecast[0,1,0]}. Forecasted DC power 2 hour ahead: {power_forecast[0,1,1]}")
print(f"Forecasted AC power 3 hour ahead: {power_forecast[0,2,0]}. Forecasted DC power 3 hour ahead: {power_forecast[0,2,1]}")
print(f"The reward we recieved was {reward}")
print(f"_________________________________________________________________________________________________________________")
print(f"")
#Evaluate the base model (no EMS, just using standby mode)
#A loop to get an average reward for the base model only perfoming the standby option
#reset the environment and save the obs
#going to run it 100 times to get a benchmark
#reset score
score = 0

obs,_    = base_env.reset()
#ensure that the exit condition is reset
truncated = False
#define the action to take
action_standby = 0

while not truncated:
    obs,reward,terminated,truncated,info = base_env.step(action_standby)
    score += reward

print(f"Done iteration! Total reward accumulated is: {score}")
# Out:
# The reset observation space looks like: {'bat_level': array([250.], dtype=float32), 'current_power_bal': array([[-35.376823, -52.2     ]], dtype=float32), 'island_forecast': array([[0., 0., 0., 0.]], dtype=float32), 'power_bal_forecast': array([[[-60.104362, -52.      ],
#         [-55.141876, -52.2     ],
#         [-12.482445, -52.2     ]]], dtype=float32), 'price_forecast': array([[1., 1., 1., 1.]], dtype=float32)}
# Battery level is: 250.0kWh
# Current AC Power Balance -35.37682342529297, Current DC Power Balance-52.20000076293945
# Forecasted AC power 1 hour ahead: -60.10436248779297. Forecasted DC power 1 hour ahead: -52.0
# Forecasted AC power 2 hour ahead: -55.141876220703125. Forecasted DC power 2 hour ahead: -52.20000076293945
# Forecasted AC power 3 hour ahead: -12.482444763183594. Forecasted DC power 3 hour ahead: -52.20000076293945
# The reward we recieved was [0. 0. 0. 0. 0.]
# _________________________________________________________________________________________________________________
#
# After action 0:
# Battery level is: 162.4231719970703kWh
# Current AC Power Balance -60.10436248779297, Current DC Power Balance-52.0
# Forecasted AC power 1 hour ahead: -55.141876220703125. Forecasted DC power 1 hour ahead: -52.20000076293945
# Forecasted AC power 2 hour ahead: -12.482444763183594. Forecasted DC power 2 hour ahead: -52.20000076293945
# Forecasted AC power 3 hour ahead: 69.41790008544922. Forecasted DC power 3 hour ahead: -52.20000076293945
# The reward we recieved was 0.0
# _________________________________________________________________________________________________________________
#
# After action 0:
# Battery level is: 100.0kWh
# Current AC Power Balance -55.141876220703125, Current DC Power Balance-52.20000076293945
# Forecasted AC power 1 hour ahead: -12.482444763183594. Forecasted DC power 1 hour ahead: -52.20000076293945
# Forecasted AC power 2 hour ahead: 69.41790008544922. Forecasted DC power 2 hour ahead: -52.20000076293945
# Forecasted AC power 3 hour ahead: 141.04750061035156. Forecasted DC power 3 hour ahead: -51.5
# The reward we recieved was -49.681190490722656
# _________________________________________________________________________________________________________________
#
# After action 1 :
# Battery level is: 500.0kWh
# Current AC Power Balance -12.482444763183594, Current DC Power Balance-52.20000076293945
# Forecasted AC power 1 hour ahead: 69.41790008544922. Forecasted DC power 1 hour ahead: -52.20000076293945
# Forecasted AC power 2 hour ahead: 141.04750061035156. Forecasted DC power 2 hour ahead: -51.5
# Forecasted AC power 3 hour ahead: 286.2445068359375. Forecasted DC power 3 hour ahead: -24.50701141357422
# The reward we recieved was -507.3418731689453
# _________________________________________________________________________________________________________________
#
# Done iteration! Total reward accumulated is: -831059.8218307495

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **LOAD OR MAKE MODEL HERE!**

# %%
config = {
    "policy_type": "MultiInputPolicy",
    "total_timesteps": 1_500_000,
}

run = wandb.init(
    project="4022_intelligent_ems",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)

train_args = {
                "episode_len"   : 6000,
                "actual_load"   : actual_load,
                "actual_gen"    : actual_gen,
                "bat_threshold" : 100,
                "bat_cap"       : 500,
                "purchase_price": purchase_price,
                "num_preds"     : 3,
                "load_shedding" : load_shedding[2760:],
                "render_mode"   : "rgb_array",
                "wandb_log"     : True,
                "train_log"     : True,

                }

eval_args = {
                "episode_len"   :2760,
                "actual_load"   :actual_load[6001:],
                "actual_gen"    :actual_gen[6001:],
                "bat_threshold" :100,
                "bat_cap"       :500,
                "purchase_price":purchase_price[6001:],
                "num_preds"     :3,
                "load_shedding" :load_shedding[6001:],
                "wandb_log"     : True,
                "train_log"     : False
}

#define 5 environments   for training and eval
n_envs = 5
n_eval_episodes =1
train_env = make_vec_env(EMS, n_envs = n_envs,env_kwargs = train_args )


eval_env = make_vec_env(EMS, n_envs = n_envs,env_kwargs = eval_args )


wand_eval = f"{version}_{model_type}_eval"+datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
wand_train = f"{version}_{model_type}_train"+datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

wandb_callback = WandbCallback(
                gradient_save_freq=100,
                model_save_path=f"models/{run.id}.{datetime.datetime.now()}",
                model_save_freq= 30000,
                verbose=2,
                log = "all",
               )
eval_callback = EvalCallback(eval_env,
                             best_model_save_path = f"{model_dir}{version}_{model_type}"+datetime.datetime.now().strftime("%Y%m%d-%H%M%S"),
                             log_path = wand_eval,
                             eval_freq=300,
                             n_eval_episodes = n_eval_episodes,
                             deterministic = True,
                             render = False,
                             callback_after_eval = wandb_callback)


model = PPO("MultiInputPolicy",train_env, verbose = 1, tensorboard_log = f"runs/{run.id}") #log_dir

model.learn(total_timesteps= config["total_timesteps"],
            tb_log_name = wand_train,
            reset_num_timesteps=False,
            callback = wandb_callback
            )

model.save(f"{model_dir}{version}_{model_type}"+datetime.datetime.now().strftime("%m%d-%H%M%S"))
run.finish()
# Out:
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/EEE4022S_BNKJUL001_Thesis/wandb/run-20231009_112040-5blobtn8</code>
# Syncing run <strong><a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/5blobtn8' target="_blank">dulcet-totem-72</a></strong> to <a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems' target="_blank">https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems</a>
#  View run at <a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/5blobtn8' target="_blank">https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/5blobtn8</a>
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cpu device
# Logging to runs/5blobtn8/EMSv1_0_PPO_2_train20231009-112041_0
# ------------------------------
# | time/              |       |
# |    fps             | 3152  |
# |    iterations      | 1     |
# |    time_elapsed    | 3     |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 663         |
# |    iterations           | 2           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013545188 |
# |    clip_fraction        | 0.0244      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.000126   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.98e+06    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0032     |
# |    value_loss           | 4.16e+06    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6e+03         |
# |    ep_rew_mean          | -9.02e+05     |
# | time/                   |               |
# |    fps                  | 679           |
# |    iterations           | 3             |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00038438052 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.681        |
# |    explained_variance   | -5.84e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.19e+06      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000378     |
# |    value_loss           | 9.81e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6e+03         |
# |    ep_rew_mean          | -9.02e+05     |
# | time/                   |               |
# |    fps                  | 722           |
# |    iterations           | 4             |
# |    time_elapsed         | 56            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 4.8167167e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.683        |
# |    explained_variance   | -5.36e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.8e+06       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000208     |
# |    value_loss           | 1.31e+07      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6e+03       |
# |    ep_rew_mean          | -9.02e+05   |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 5           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010373391 |
# |    clip_fraction        | 0.00714     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 1.85e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.32e+06    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00187    |
# |    value_loss           | 4.46e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.99e+05    |
# | time/                   |              |
# |    fps                  | 763          |
# |    iterations           | 6            |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0017805621 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.657       |
# |    explained_variance   | 3.1e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.94e+06     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 1.09e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.99e+05    |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 7            |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0009427527 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.651       |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6e+06        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000716    |
# |    value_loss           | 1.17e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.99e+05    |
# | time/                   |              |
# |    fps                  | 767          |
# |    iterations           | 8            |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0077987676 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.612       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25e+06     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 4.65e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.95e+05    |
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 9            |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0018700457 |
# |    clip_fraction        | 0.0011       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.604       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.36e+06     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 1.15e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6e+03         |
# |    ep_rew_mean          | -8.95e+05     |
# | time/                   |               |
# |    fps                  | 791           |
# |    iterations           | 10            |
# |    time_elapsed         | 129           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 0.00092391914 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.574        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.37e+06      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.00104      |
# |    value_loss           | 1.06e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.95e+05    |
# | time/                   |              |
# |    fps                  | 794          |
# |    iterations           | 11           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0027867996 |
# |    clip_fraction        | 0.00446      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.546       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.47e+06     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 4.56e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.86e+05    |
# | time/                   |              |
# |    fps                  | 799          |
# |    iterations           | 12           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0010336445 |
# |    clip_fraction        | 0.000137     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.56        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.94e+06     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 1.17e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.86e+05    |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 13           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 133120       |
# | train/                  |              |
# |    approx_kl            | 0.0014972677 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.504       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.03e+06     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 8.91e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.86e+05    |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 14           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0035732314 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.46        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19e+06     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00338     |
# |    value_loss           | 4.77e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.8e+05     |
# | time/                   |              |
# |    fps                  | 812          |
# |    iterations           | 15           |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 153600       |
# | train/                  |              |
# |    approx_kl            | 0.0012024913 |
# |    clip_fraction        | 0.000449     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.495       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.57e+06     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 1.17e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.8e+05     |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 16           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0010359951 |
# |    clip_fraction        | 0.00274      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.456       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.77e+06     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 8.48e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.8e+05     |
# | time/                   |              |
# |    fps                  | 822          |
# |    iterations           | 17           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0038891956 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.435       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.18e+06     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00371     |
# |    value_loss           | 4.75e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.73e+05    |
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 18           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0017083023 |
# |    clip_fraction        | 0.00629      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.92e+06     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 1.15e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.73e+05    |
# | time/                   |              |
# |    fps                  | 822          |
# |    iterations           | 19           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0020412304 |
# |    clip_fraction        | 0.00523      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.418       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.92e+06     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 7.82e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.73e+05    |
# | time/                   |              |
# |    fps                  | 826          |
# |    iterations           | 20           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0034544661 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.06e+06     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00316     |
# |    value_loss           | 4.26e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.65e+05    |
# | time/                   |              |
# |    fps                  | 829          |
# |    iterations           | 21           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 215040       |
# | train/                  |              |
# |    approx_kl            | 0.0011082466 |
# |    clip_fraction        | 0.00358      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.445       |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.06e+06     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 1.14e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.65e+05    |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 22           |
# |    time_elapsed         | 271          |
# |    total_timesteps      | 225280       |
# | train/                  |              |
# |    approx_kl            | 0.0016409054 |
# |    clip_fraction        | 0.00606      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.383       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.4e+06      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 7.35e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.65e+05    |
# | time/                   |              |
# |    fps                  | 829          |
# |    iterations           | 23           |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 235520       |
# | train/                  |              |
# |    approx_kl            | 0.0010420897 |
# |    clip_fraction        | 0.00309      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.368       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.94e+06     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 4.57e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6e+03       |
# |    ep_rew_mean          | -8.59e+05   |
# | time/                   |             |
# |    fps                  | 831         |
# |    iterations           | 24          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.001168234 |
# |    clip_fraction        | 0.00251     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.402      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.96e+06    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 1.14e+07    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6e+03         |
# |    ep_rew_mean          | -8.59e+05     |
# | time/                   |               |
# |    fps                  | 833           |
# |    iterations           | 25            |
# |    time_elapsed         | 306           |
# |    total_timesteps      | 256000        |
# | train/                  |               |
# |    approx_kl            | 0.00087731704 |
# |    clip_fraction        | 0.0048        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.323        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.67e+06      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.00208      |
# |    value_loss           | 6.51e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.59e+05    |
# | time/                   |              |
# |    fps                  | 833          |
# |    iterations           | 26           |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 266240       |
# | train/                  |              |
# |    approx_kl            | 0.0013733173 |
# |    clip_fraction        | 0.00445      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.342       |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.3e+06      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 5.16e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.55e+05    |
# | time/                   |              |
# |    fps                  | 832          |
# |    iterations           | 27           |
# |    time_elapsed         | 331          |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0010810979 |
# |    clip_fraction        | 0.00612      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.374       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.14e+06     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 1.15e+07     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6e+03      |
# |    ep_rew_mean          | -8.55e+05  |
# | time/                   |            |
# |    fps                  | 836        |
# |    iterations           | 28         |
# |    time_elapsed         | 342        |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.00202835 |
# |    clip_fraction        | 0.0146     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.301     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.37e+06   |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00383   |
# |    value_loss           | 5.9e+06    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.55e+05    |
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 29           |
# |    time_elapsed         | 354          |
# |    total_timesteps      | 296960       |
# | train/                  |              |
# |    approx_kl            | 0.0012571942 |
# |    clip_fraction        | 0.00481      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.336       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.4e+06      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 6.12e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.51e+05    |
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 30           |
# |    time_elapsed         | 366          |
# |    total_timesteps      | 307200       |
# | train/                  |              |
# |    approx_kl            | 0.0015623231 |
# |    clip_fraction        | 0.00387      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.359       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.52e+06     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 1.08e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 6e+03         |
# |    ep_rew_mean          | -8.51e+05     |
# | time/                   |               |
# |    fps                  | 837           |
# |    iterations           | 31            |
# |    time_elapsed         | 379           |
# |    total_timesteps      | 317440        |
# | train/                  |               |
# |    approx_kl            | 0.00089717505 |
# |    clip_fraction        | 0.0077        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.281        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.27e+06      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.0031       |
# |    value_loss           | 5.33e+06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6e+03       |
# |    ep_rew_mean          | -8.51e+05   |
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 32          |
# |    time_elapsed         | 389         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.001553439 |
# |    clip_fraction        | 0.00656     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.345      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.84e+06    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00224    |
# |    value_loss           | 6.73e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.48e+05    |
# | time/                   |              |
# |    fps                  | 840          |
# |    iterations           | 33           |
# |    time_elapsed         | 401          |
# |    total_timesteps      | 337920       |
# | train/                  |              |
# |    approx_kl            | 0.0026962564 |
# |    clip_fraction        | 0.0098       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.358       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.05e+06     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 1.09e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.48e+05    |
# | time/                   |              |
# |    fps                  | 840          |
# |    iterations           | 34           |
# |    time_elapsed         | 414          |
# |    total_timesteps      | 348160       |
# | train/                  |              |
# |    approx_kl            | 0.0020540592 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.274       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.15e+06     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 4.8e+06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.48e+05    |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 35           |
# |    time_elapsed         | 425          |
# |    total_timesteps      | 358400       |
# | train/                  |              |
# |    approx_kl            | 0.0012601034 |
# |    clip_fraction        | 0.00496      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.336       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.88e+06     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 6.74e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6e+03       |
# |    ep_rew_mean          | -8.44e+05   |
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 36          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.000978792 |
# |    clip_fraction        | 0.00563     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.344      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.17e+06    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 1.08e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.44e+05    |
# | time/                   |              |
# |    fps                  | 843          |
# |    iterations           | 37           |
# |    time_elapsed         | 449          |
# |    total_timesteps      | 378880       |
# | train/                  |              |
# |    approx_kl            | 0.0017969083 |
# |    clip_fraction        | 0.00891      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.258       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+06      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0027      |
# |    value_loss           | 3.79e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.44e+05    |
# | time/                   |              |
# |    fps                  | 843          |
# |    iterations           | 38           |
# |    time_elapsed         | 461          |
# |    total_timesteps      | 389120       |
# | train/                  |              |
# |    approx_kl            | 0.0009944641 |
# |    clip_fraction        | 0.00722      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.333       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.1e+06      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 7.41e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.4e+05     |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 39           |
# |    time_elapsed         | 472          |
# |    total_timesteps      | 399360       |
# | train/                  |              |
# |    approx_kl            | 0.0010919371 |
# |    clip_fraction        | 0.00532      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.353       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.96e+06     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 1.1e+07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.4e+05     |
# | time/                   |              |
# |    fps                  | 846          |
# |    iterations           | 40           |
# |    time_elapsed         | 483          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0024409317 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.245       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63e+06     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 2.48e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.37e+05    |
# | time/                   |              |
# |    fps                  | 846          |
# |    iterations           | 41           |
# |    time_elapsed         | 495          |
# |    total_timesteps      | 419840       |
# | train/                  |              |
# |    approx_kl            | 0.0013195332 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.339       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.2e+06      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 7.14e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.37e+05    |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 42           |
# |    time_elapsed         | 508          |
# |    total_timesteps      | 430080       |
# | train/                  |              |
# |    approx_kl            | 0.0014612211 |
# |    clip_fraction        | 0.00534      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.336       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.81e+06     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 1.05e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.37e+05    |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 43           |
# |    time_elapsed         | 519          |
# |    total_timesteps      | 440320       |
# | train/                  |              |
# |    approx_kl            | 0.0017119687 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43e+06     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00324     |
# |    value_loss           | 2.65e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.33e+05    |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 44           |
# |    time_elapsed         | 531          |
# |    total_timesteps      | 450560       |
# | train/                  |              |
# |    approx_kl            | 0.0009774922 |
# |    clip_fraction        | 0.00604      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.12e+06     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 7.4e+06      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6e+03       |
# |    ep_rew_mean          | -8.33e+05   |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 45          |
# |    time_elapsed         | 543         |
# |    total_timesteps      | 460800      |
# | train/                  |             |
# |    approx_kl            | 0.001899962 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.314      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.82e+06    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00267    |
# |    value_loss           | 9.51e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6e+03       |
# |    ep_rew_mean          | -8.33e+05   |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 46          |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.001861744 |
# |    clip_fraction        | 0.0155      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.26       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83e+06    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00336    |
# |    value_loss           | 2.75e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.3e+05     |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 47           |
# |    time_elapsed         | 567          |
# |    total_timesteps      | 481280       |
# | train/                  |              |
# |    approx_kl            | 0.0021690358 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.351       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.69e+06     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 8.1e+06      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6e+03       |
# |    ep_rew_mean          | -8.3e+05    |
# | time/                   |             |
# |    fps                  | 848         |
# |    iterations           | 48          |
# |    time_elapsed         | 579         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.001741441 |
# |    clip_fraction        | 0.0114      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.312      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.41e+06    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00353    |
# |    value_loss           | 8.44e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.3e+05     |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 49           |
# |    time_elapsed         | 592          |
# |    total_timesteps      | 501760       |
# | train/                  |              |
# |    approx_kl            | 0.0024470384 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.277       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19e+06     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 3.14e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.27e+05    |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 50           |
# |    time_elapsed         | 604          |
# |    total_timesteps      | 512000       |
# | train/                  |              |
# |    approx_kl            | 0.0013744242 |
# |    clip_fraction        | 0.00803      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.354       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.66e+06     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 8.36e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.27e+05    |
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 51           |
# |    time_elapsed         | 615          |
# |    total_timesteps      | 522240       |
# | train/                  |              |
# |    approx_kl            | 0.0012423882 |
# |    clip_fraction        | 0.0076       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.304       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.44e+06     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 7.5e+06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.27e+05    |
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 52           |
# |    time_elapsed         | 627          |
# |    total_timesteps      | 532480       |
# | train/                  |              |
# |    approx_kl            | 0.0021616297 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.266       |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+06     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0037      |
# |    value_loss           | 3.21e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -8.25e+05    |
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 53           |
# |    time_elapsed         | 639          |
# |    total_timesteps      | 542720       |
# | train/                  |              |
# |    approx_kl            | 0.0015724357 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.353       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.3e+06      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 9.04e+06     |
# ------------------------------------------
# ...
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -7.7e+05     |
# | time/                   |              |
# |    fps                  | 846          |
# |    iterations           | 135          |
# |    time_elapsed         | 1633         |
# |    total_timesteps      | 1382400      |
# | train/                  |              |
# |    approx_kl            | 0.0031714612 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.314       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.52e+06     |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 6.99e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6e+03       |
# |    ep_rew_mean          | -7.7e+05    |
# | time/                   |             |
# |    fps                  | 845         |
# |    iterations           | 136         |
# |    time_elapsed         | 1646        |
# |    total_timesteps      | 1392640     |
# | train/                  |             |
# |    approx_kl            | 0.003081493 |
# |    clip_fraction        | 0.0197      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.26       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89e+06    |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | -0.00267    |
# |    value_loss           | 4.67e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6e+03       |
# |    ep_rew_mean          | -7.7e+05    |
# | time/                   |             |
# |    fps                  | 845         |
# |    iterations           | 137         |
# |    time_elapsed         | 1659        |
# |    total_timesteps      | 1402880     |
# | train/                  |             |
# |    approx_kl            | 0.003066726 |
# |    clip_fraction        | 0.0211      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.256      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+06    |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 2.44e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -7.7e+05     |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 138          |
# |    time_elapsed         | 1671         |
# |    total_timesteps      | 1413120      |
# | train/                  |              |
# |    approx_kl            | 0.0033608116 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.328       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.56e+06     |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 6.78e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -7.7e+05     |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 139          |
# |    time_elapsed         | 1683         |
# |    total_timesteps      | 1423360      |
# | train/                  |              |
# |    approx_kl            | 0.0017570592 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.269       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.34e+06     |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00394     |
# |    value_loss           | 5.49e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -7.7e+05     |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 140          |
# |    time_elapsed         | 1696         |
# |    total_timesteps      | 1433600      |
# | train/                  |              |
# |    approx_kl            | 0.0034558685 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.252       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.05e+06     |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 2.38e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -7.71e+05    |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 141          |
# |    time_elapsed         | 1708         |
# |    total_timesteps      | 1443840      |
# | train/                  |              |
# |    approx_kl            | 0.0022249727 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.321       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.5e+06      |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 7.19e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6e+03       |
# |    ep_rew_mean          | -7.71e+05   |
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 142         |
# |    time_elapsed         | 1721        |
# |    total_timesteps      | 1454080     |
# | train/                  |             |
# |    approx_kl            | 0.002179963 |
# |    clip_fraction        | 0.0169      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.27       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.72e+06    |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.0026     |
# |    value_loss           | 4.89e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -7.71e+05    |
# | time/                   |              |
# |    fps                  | 844          |
# |    iterations           | 143          |
# |    time_elapsed         | 1733         |
# |    total_timesteps      | 1464320      |
# | train/                  |              |
# |    approx_kl            | 0.0032342058 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.255       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+06     |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | -0.00449     |
# |    value_loss           | 2.5e+06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -7.7e+05     |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 144          |
# |    time_elapsed         | 1744         |
# |    total_timesteps      | 1474560      |
# | train/                  |              |
# |    approx_kl            | 0.0018291969 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.312       |
# |    explained_variance   | 0.000107     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.29e+06     |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | -0.00327     |
# |    value_loss           | 6.96e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -7.7e+05     |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 145          |
# |    time_elapsed         | 1757         |
# |    total_timesteps      | 1484800      |
# | train/                  |              |
# |    approx_kl            | 0.0014608434 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | 5.36e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.3e+06      |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 4.39e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -7.7e+05     |
# | time/                   |              |
# |    fps                  | 844          |
# |    iterations           | 146          |
# |    time_elapsed         | 1769         |
# |    total_timesteps      | 1495040      |
# | train/                  |              |
# |    approx_kl            | 0.0027240184 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.262       |
# |    explained_variance   | 0.0131       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76e+06     |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 2.94e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6e+03        |
# |    ep_rew_mean          | -7.71e+05    |
# | time/                   |              |
# |    fps                  | 844          |
# |    iterations           | 147          |
# |    time_elapsed         | 1781         |
# |    total_timesteps      | 1505280      |
# | train/                  |              |
# |    approx_kl            | 0.0023891747 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.31        |
# |    explained_variance   | 0.000425     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.79e+06     |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 7.29e+06     |
# ------------------------------------------
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.851 MB of 0.851 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Excess Generation</td><td>██▇▅▅▃▃▃▂▃▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Num Off-Peak Purchases</td><td>█▆▅▃▃▁▁▂▁▂▂▃▂▃▂▃▂▃▂▂▂▂▃▃▃▂▂▂▂▁▂▃▃▃▄▅▆▄▅▅</td></tr><tr><td>Num Peak Purchases</td><td>█▅▅▄▄▁▃▅▂▃▂▂▂▃▃▃▂▂▁▃▂▂▃▄▂▂▂▁▁▂▃▂▁▃▁▃▃▂▃▃</td></tr><tr><td>Num Purchase Count</td><td>█▆▅▄▃▂▂▁▁▁▁▁▂▂▂▁▂▂▂▂▂▂▂▂▁▁▂▂▁▁▁▂▂▂▂▃▃▂▃▂</td></tr><tr><td>Num Standard Purchases</td><td>█▇▅▂▄▁▂▂▁▂▃▃▃▃▄▂▄▆▄▅▃▃▄▄▃▄▄▅▄▃▃▅▆▆▅▆▆▇▇▆</td></tr><tr><td>Num Standby Actions</td><td>▁▂▄▅▆▇▇█████▇▇▇█▇▇▇▇▇▇▇▇██▇▇███▇▇▇▇▆▆▇▇▇</td></tr><tr><td>Off-Peak Purchases</td><td>██▇▆▅▅▄▄▄▃▃▄▃▃▃▂▃▂▃▂▃▃▂▂▂▃▂▂▃▂▂▂▂▂▂▂▃▁▂▂</td></tr><tr><td>Peak Purchases</td><td>██▇█▆▄▆▄▄▃▃▄▂▂▃▃▂▁▁▃▂▂▂▃▂▂▃▁▂▃▃▁▁▁▂▂▂▁▁▂</td></tr><tr><td>Standard Purchases</td><td>▇▆▅▁▅▄▃▃▂▄▃▁▅▄▄▃▄▆▅▅▃▃▄▅▄▄▅▆▂▄▃▇▆▆▅▅▄█▆▅</td></tr><tr><td>Unmet Load</td><td>▅▅▆█▄▅▄▆▆▆▅▃▄▃▄▅▄▂▄▂▄▃▄▁▇▅▅▄▂▄▃▁▄▁▃▂▁▁▃▅</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▂▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇▇▇███████████████</td></tr><tr><td>time/fps</td><td>▁▃▅▆▇▇▇▇████████████████████████████████</td></tr><tr><td>train/approx_kl</td><td>▁█▂▂▃▂▁▁▁▂▁▂▂▂▂▂▂▃▂▂▂▂▃▃▂▃▃▂▃▂▃▃▂▃▂▂▃▂▃▂</td></tr><tr><td>train/clip_fraction</td><td>▁▂▁▁▆▂▂▂▃▂▂▄▃▂▃▃▅▅▅▄▅▃▄▇▄▅▆▅▆▃▆▅▅▅▅▅▅▅█▅</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▂▄▅▅▆▆▇▆▆█▆▇▆▇▇▆█▇█▇▇█▆▇▇▇▇▇█▇▆▆▇█▆▇▇▇</td></tr><tr><td>train/explained_variance</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▅▃█▆▃█▅▆▄▄▇▂▆▆▅▄▄▅▃▄▂▅▇▁▄▃▁▂▃▅▂▃▆▂▄▁▄▃▂▅</td></tr><tr><td>train/policy_gradient_loss</td><td>█▅▆▆▂▅▅▅▃▄▅▃▄▄▄▃▃▁▄▄▃▅▃▄▄▃▃▂▃▃▃▂▄▃▄▆▄▂▁▃</td></tr><tr><td>train/value_loss</td><td>▇▃█▆▃█▄█▃▄█▁▅▅▆▄▂▆▃▃▂▄▆▁▅▄▁▄▂▅▂▃▆▃▄▁▅▃▁▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Excess Generation</td><td>537675.35266</td></tr><tr><td>Num Off-Peak Purchases</td><td>1016</td></tr><tr><td>Num Peak Purchases</td><td>307</td></tr><tr><td>Num Purchase Count</td><td>1202</td></tr><tr><td>Num Standard Purchases</td><td>487</td></tr><tr><td>Num Standby Actions</td><td>4840</td></tr><tr><td>Off-Peak Purchases</td><td>250841.08384</td></tr><tr><td>Peak Purchases</td><td>72741.23233</td></tr><tr><td>Standard Purchases</td><td>117098.52288</td></tr><tr><td>Unmet Load</td><td>7518.8635</td></tr><tr><td>global_step</td><td>1505280</td></tr><tr><td>rollout/ep_len_mean</td><td>5995.0</td></tr><tr><td>rollout/ep_rew_mean</td><td>-770857.75</td></tr><tr><td>time/fps</td><td>844.0</td></tr><tr><td>train/approx_kl</td><td>0.00239</td></tr><tr><td>train/clip_fraction</td><td>0.01979</td></tr><tr><td>train/clip_range</td><td>0.2</td></tr><tr><td>train/entropy_loss</td><td>-0.3105</td></tr><tr><td>train/explained_variance</td><td>0.00043</td></tr><tr><td>train/learning_rate</td><td>0.0003</td></tr><tr><td>train/loss</td><td>3788296.25</td></tr><tr><td>train/policy_gradient_loss</td><td>-0.0031</td></tr><tr><td>train/value_loss</td><td>7285851.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dulcet-totem-72</strong> at: <a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/5blobtn8' target="_blank">https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/5blobtn8</a><br/>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20231009_112040-5blobtn8/logs</code>

# %%
run.finish()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Define a new test environment and load up the best performing model to test it.**

# %%
config = {
    "policy_type": "MultiInputPolicy",
    "total_timesteps": 2760,
}
run = wandb.init(
    project="4022_intelligent_ems",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)
#Load model, fetch the latest (or whichever one you want from the model_dir)
#Best A2C model:/content/drive/MyDrive/Colab Notebooks/EMSv0_3/models/PPO/EMSv0_3_PPO20231005-102532.zip
#best_PPO_model = "EMSv0_3_PPO20231006-204045"

#model_load = f"{model_dir}/{best_PPO_model}"
#model  = PPO.load(model_load, env = eval_env)

#first run it with only standby (default)
obs   = eval_env.reset()
#ensure that the exit condition is reset
done = [False]*n_envs
#define the action to take
action_standby = [0]*n_envs
#reset score
standby_score = [0]*n_envs
standby_score = np.array(standby_score).astype(np.float32)
while not all(done):
    #step the model with the action
    obs,reward,done,info = eval_env.step(action_standby)
    #accumulate the score
    standby_score += reward

avg_standby_score = standby_score.mean()

run.finish()

run = wandb.init(
    project="4022_intelligent_ems",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)
obs   = eval_env.reset()
EMS_reward,EMS_std_reward = evaluate_policy(model,eval_env,n_eval_episodes = 1,deterministic=True)# callback = wandb_callback
run.finish()

print(f"Note: The term does not refer to the cost in rands but rather to the reward as defined by the reward function!")
print(f"Done the Standby Test! Total cost accumulated is: {avg_standby_score}")
print(f"Done applying the trained model! Total cost accumulated is: {EMS_reward} +- {EMS_std_reward}")

savings = EMS_reward - avg_standby_score
print(f"The amount that was saved by applying the EMS agent: {savings}")
print(f"This was saved over a period of {2760/24} days")
print(f"The savings represents {(savings/(-avg_standby_score))*100} % of the cost if no EMS is installed")
print(f"And it represents {(savings/(-EMS_reward))*100} % of the cost if the EMS is installed")
# Out:
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/EEE4022S_BNKJUL001_Thesis/wandb/run-20231009_115047-oaz4vea5</code>
# Syncing run <strong><a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/oaz4vea5' target="_blank">stoic-sky-73</a></strong> to <a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems' target="_blank">https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems</a>
#  View run at <a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/oaz4vea5' target="_blank">https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/oaz4vea5</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AC load</td><td>▄▅█▅▃▅▃▇▃▆▂▂▅▅█▄▄▂▂▆▅▂▂▂▄▁▂▁▁▆▁▆▁▁▃▅▆▃▁▃</td></tr><tr><td>Current_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>DC load</td><td>▁▁▂▁▃▂▁▆▂▃▂▂▃▁▄▄▂▂▁▇▁▂▂▄█▃▂▂▂▃▁▂▂▂▄▄▃▁▁▁</td></tr><tr><td>Excess Generation</td><td>▁▁▁▁▂▂▂▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>LoadShedding</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁█▁</td></tr><tr><td>Num Off-Peak Purchases</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>Num Peak Purchases</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇████</td></tr><tr><td>Num Purchase Count</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Num Standard Purchases</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▅▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇█████</td></tr><tr><td>Num Standby Actions</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Off-Peak Purchases</td><td>▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇████</td></tr><tr><td>PV generation</td><td>▁▁▁▆█▁▁▁▅▆▃▁▁▄▆▄▁▄▁██▃█▂▆▅▇▅▁▁█▄▅▁▁▇▇▁▁▁</td></tr><tr><td>Peak Purchases</td><td>▁▁▁▂▂▂▃▃▃▃▄▄▅▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇████████</td></tr><tr><td>Standard Purchases</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇████</td></tr><tr><td>Unmet Load</td><td>▁▁▁▂▂▂▃▃▄▄▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▇▇███</td></tr><tr><td>Wind generation</td><td>▁▁█▃▁▁▁▂▆▂▁▁▁▇▃▁▁▁▃▆▃▁▁▁▇▆▁▁▁▂▄▂▁▁▁▇▆▁▁▁</td></tr><tr><td>battery_level</td><td>▁▁▂██▁▁▁███▁▁██▅▁█▁████▁████▁▁███▂▁██▃▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AC load</td><td>88.491</td></tr><tr><td>Current_step</td><td>2755</td></tr><tr><td>DC load</td><td>52.4</td></tr><tr><td>Excess Generation</td><td>319865.63832</td></tr><tr><td>LoadShedding</td><td>0.0</td></tr><tr><td>Num Off-Peak Purchases</td><td>568</td></tr><tr><td>Num Peak Purchases</td><td>125</td></tr><tr><td>Num Purchase Count</td><td>0</td></tr><tr><td>Num Standard Purchases</td><td>137</td></tr><tr><td>Num Standby Actions</td><td>2755</td></tr><tr><td>Off-Peak Purchases</td><td>84994.41991</td></tr><tr><td>PV generation</td><td>342.20319</td></tr><tr><td>Peak Purchases</td><td>16638.24617</td></tr><tr><td>Standard Purchases</td><td>21632.66076</td></tr><tr><td>Unmet Load</td><td>9653.63237</td></tr><tr><td>Wind generation</td><td>0.0</td></tr><tr><td>battery_level</td><td>500.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stoic-sky-73</strong> at: <a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/oaz4vea5' target="_blank">https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/oaz4vea5</a><br/>Synced 4 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231009_115047-oaz4vea5/logs</code>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/EEE4022S_BNKJUL001_Thesis/wandb/run-20231009_115151-94ums69y</code>
# Syncing run <strong><a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/94ums69y' target="_blank">playful-dust-74</a></strong> to <a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems' target="_blank">https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems</a>
#  View run at <a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/94ums69y' target="_blank">https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/94ums69y</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AC load</td><td>▄▅█▅▃▅▃▇▃▆▂▂▅▅█▄▄▂▂▆▅▂▂▂▄▁▂▁▁▆▁▆▁▁▃▅▆▃▁▃</td></tr><tr><td>Current_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>DC load</td><td>▁▁▂▁▃▂▁▆▂▃▂▂▃▁▄▄▂▂▁▇▁▂▂▄█▃▂▂▂▃▁▂▂▂▄▄▃▁▁▁</td></tr><tr><td>Excess Generation</td><td>▁▁▁▁▂▂▂▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>LoadShedding</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁█▁</td></tr><tr><td>Num Off-Peak Purchases</td><td>▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>Num Peak Purchases</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇████</td></tr><tr><td>Num Purchase Count</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇████</td></tr><tr><td>Num Standard Purchases</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇████████</td></tr><tr><td>Num Standby Actions</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Off-Peak Purchases</td><td>▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>PV generation</td><td>▁▁▁▆█▁▁▁▅▆▃▁▁▄▆▄▁▄▁██▃█▂▆▅▇▅▁▁█▄▅▁▁▇▇▁▁▁</td></tr><tr><td>Peak Purchases</td><td>▁▁▁▂▂▂▃▃▃▃▄▄▅▅▅▆▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇████</td></tr><tr><td>Standard Purchases</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇██████</td></tr><tr><td>Unmet Load</td><td>▁▁▂▂▃▃▄▄▄▄▅▅▅▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▆▆▇▇███</td></tr><tr><td>Wind generation</td><td>▁▁█▃▁▁▁▂▆▂▁▁▁▇▃▁▁▁▃▆▃▁▁▁▇▆▁▁▁▂▄▂▁▁▁▇▆▁▁▁</td></tr><tr><td>battery_level</td><td>▂▁▂██▂█▁███▅███▅██▁████▅█████████████▆▆▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AC load</td><td>88.491</td></tr><tr><td>Current_step</td><td>2755</td></tr><tr><td>DC load</td><td>52.4</td></tr><tr><td>Excess Generation</td><td>320549.13189</td></tr><tr><td>LoadShedding</td><td>0.0</td></tr><tr><td>Num Off-Peak Purchases</td><td>391</td></tr><tr><td>Num Peak Purchases</td><td>104</td></tr><tr><td>Num Purchase Count</td><td>274</td></tr><tr><td>Num Standard Purchases</td><td>108</td></tr><tr><td>Num Standby Actions</td><td>2509</td></tr><tr><td>Off-Peak Purchases</td><td>94007.80964</td></tr><tr><td>PV generation</td><td>342.20319</td></tr><tr><td>Peak Purchases</td><td>13655.3732</td></tr><tr><td>Standard Purchases</td><td>21938.57925</td></tr><tr><td>Unmet Load</td><td>4000.69067</td></tr><tr><td>Wind generation</td><td>0.0</td></tr><tr><td>battery_level</td><td>500.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">playful-dust-74</strong> at: <a href='https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/94ums69y' target="_blank">https://wandb.ai/4022_intelligent_ems/4022_intelligent_ems/runs/94ums69y</a><br/>Synced 4 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20231009_115151-94ums69y/logs</code>
# Note: The term does not refer to the cost in rands but rather to the reward as defined by the reward function!
# Done the Standby Test! Total cost accumulated is: -274710.90625
# Done applying the trained model! Total cost accumulated is: -218857.994446 +- 0.0
# The amount that was saved by applying the EMS agent: 55852.911804
# This was saved over a period of 115.0 days
# The savings represents 20.33152326073694 % of the cost if no EMS is installed
# And it represents 25.520160661885665 % of the cost if the EMS is installed
