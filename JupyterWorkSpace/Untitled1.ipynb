# %%
# !pip install gymnasium
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: gymnasium in c:\anaconda3\envs\tensorflow\lib\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from gymnasium) (1.26.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from gymnasium) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: stable-baselines3[extra] in c:\anaconda3\envs\tensorflow\lib\site-packages (2.1.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (1.26.0)
# Requirement already satisfied: torch>=1.13 in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: cloudpickle in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: matplotlib in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (3.8.0)
# Requirement already satisfied: opencv-python in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (4.8.1.78)
# Requirement already satisfied: pygame in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (2.14.1)
# Requirement already satisfied: psutil in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: tqdm in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (4.66.1)
# Requirement already satisfied: rich in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (13.5.3)
# Requirement already satisfied: shimmy[atari]~=1.1.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (1.1.0)
# Requirement already satisfied: pillow in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (10.0.1)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: click in c:\anaconda3\envs\tensorflow\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: requests in c:\anaconda3\envs\tensorflow\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.31.0)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\anaconda3\envs\tensorflow\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: ale-py~=0.8.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from shimmy[atari]~=1.1.0->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in c:\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.48.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: protobuf>=3.19.6 in c:\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.24.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (68.0.0)
# Requirement already satisfied: six>1.9 in c:\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: filelock in c:\anaconda3\envs\tensorflow\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.12.4)
# Requirement already satisfied: sympy in c:\anaconda3\envs\tensorflow\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (1.12)
# Requirement already satisfied: networkx in c:\anaconda3\envs\tensorflow\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in c:\anaconda3\envs\tensorflow\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->stable-baselines3[extra]) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from rich->stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: colorama in c:\anaconda3\envs\tensorflow\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: importlib-resources in c:\anaconda3\envs\tensorflow\lib\site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.1.0->stable-baselines3[extra]) (6.1.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: urllib3<2.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda3\envs\tensorflow\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\envs\tensorflow\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\envs\tensorflow\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\anaconda3\envs\tensorflow\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\anaconda3\envs\tensorflow\lib\site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\anaconda3\envs\tensorflow\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\anaconda3\envs\tensorflow\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)

# %%
import gymnasium as gym
from stable_baselines3 import A2C

env = gym.make('CartPole-v1', render_mode="rgb_array")
model = A2C("MlpPolicy", env, verbose =1)
model.learn(total_timesteps=10_000)
vec_env = model.get_env()
obs = vec_env.reset()
for i in range (1000):
  action,_state = model.predict(obs,deterministic = True)
  obs,reward,done,info = vec_env.step(action)
  vec_env.render("human")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorboard\compat\__init__.py:42, in tf()
#      41 try:
# ---> 42     from tensorboard.compat import notf  # noqa: F401
#      43 except ImportError:
#
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorboard\compat\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 import gymnasium as gym
# ----> 2 from stable_baselines3 import A2C
#       4 env = gym.make('CartPole-v1', render_mode="rgb_array")
#       5 model = A2C("MlpPolicy", env, verbose =1)
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\stable_baselines3\__init__.py:3
#       1 import os
# ----> 3 from stable_baselines3.a2c import A2C
#       4 from stable_baselines3.common.utils import get_system_info
#       5 from stable_baselines3.ddpg import DDPG
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\stable_baselines3\a2c\__init__.py:1
# ----> 1 from stable_baselines3.a2c.a2c import A2C
#       2 from stable_baselines3.a2c.policies import CnnPolicy, MlpPolicy, MultiInputPolicy
#       4 __all__ = ["CnnPolicy", "MlpPolicy", "MultiInputPolicy", "A2C"]
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\stable_baselines3\a2c\a2c.py:7
#       4 from gymnasium import spaces
#       5 from torch.nn import functional as F
# ----> 7 from stable_baselines3.common.on_policy_algorithm import OnPolicyAlgorithm
#       8 from stable_baselines3.common.policies import ActorCriticCnnPolicy, ActorCriticPolicy, BasePolicy, MultiInputActorCriticPolicy
#       9 from stable_baselines3.common.type_aliases import GymEnv, MaybeCallback, Schedule
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:9
#       6 import torch as th
#       7 from gymnasium import spaces
# ----> 9 from stable_baselines3.common.base_class import BaseAlgorithm
#      10 from stable_baselines3.common.buffers import DictRolloutBuffer, RolloutBuffer
#      11 from stable_baselines3.common.callbacks import BaseCallback
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\stable_baselines3\common\base_class.py:16
#      13 import torch as th
#      14 from gymnasium import spaces
# ---> 16 from stable_baselines3.common import utils
#      17 from stable_baselines3.common.callbacks import BaseCallback, CallbackList, ConvertCallback, ProgressBarCallback
#      18 from stable_baselines3.common.env_util import is_wrapped
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\stable_baselines3\common\utils.py:20
#      18 # Check if tensorboard is available for pytorch
#      19 try:
# ---> 20     from torch.utils.tensorboard import SummaryWriter
#      21 except ImportError:
#      22     SummaryWriter = None
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\torch\utils\tensorboard\__init__.py:12
#       9 del LooseVersion
#      10 del tensorboard
# ---> 12 from .writer import FileWriter, SummaryWriter  # noqa: F401
#      13 from tensorboard.summary.writer.record_writer import RecordWriter
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\torch\utils\tensorboard\writer.py:16
#      13 from tensorboard.summary.writer.event_file_writer import EventFileWriter
#      15 from ._convert_np import make_np
# ---> 16 from ._embedding import (
#      17     make_mat,
#      18     make_sprite,
#      19     make_tsv,
#      20     write_pbtxt,
#      21     get_embedding_info,
#      22 )
#      23 from ._onnx_graph import load_onnx_graph
#      24 from ._pytorch_graph import graph
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\torch\utils\tensorboard\_embedding.py:9
#       5 from tensorboard.compat import tf
#       6 from tensorboard.plugins.projector.projector_config_pb2 import EmbeddingInfo
# ----> 9 _HAS_GFILE_JOIN = hasattr(tf.io.gfile, "join")
#      12 def _gfile_join(a, b):
#      13     # The join API is different between tensorboard's TF stub and TF:
#      14     # https://github.com/tensorflow/tensorboard/issues/6080
#      15     # We need to try both because `tf` may point to either the stub or the real TF.
#      16     if _HAS_GFILE_JOIN:
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorboard\lazy.py:65, in lazy_load.<locals>.wrapper.<locals>.LazyModule.__getattr__(self, attr_name)
#      64 def __getattr__(self, attr_name):
# ---> 65     return getattr(load_once(self), attr_name)
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorboard\lazy.py:97, in _memoize.<locals>.wrapper(arg)
#      95     with lock:
#      96         if cache.get(arg, nothing) is nothing:
# ---> 97             cache[arg] = f(arg)
#      98 return cache[arg]
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorboard\lazy.py:50, in lazy_load.<locals>.wrapper.<locals>.load_once(self)
#      48 load_once.loading = True
#      49 try:
# ---> 50     module = load_fn()
#      51 finally:
#      52     load_once.loading = False
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorboard\compat\__init__.py:45, in tf()
#      43 except ImportError:
#      44     try:
# ---> 45         import tensorflow
#      47         return tensorflow
#      48     except ImportError:
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorflow\__init__.py:38
#      35 import sys as _sys
#      36 import typing as _typing
# ---> 38 from tensorflow.python.tools import module_util as _module_util
#      39 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      41 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorflow\python\__init__.py:37
#      29 # We aim to keep this file minimal and ideally remove completely.
#      30 # If you are adding a new file with @tf_export decorators,
#      31 # import it in modules_with_exports.py instead.
#      32
#      33 # go/tf-wildcard-import
#      34 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
#      42 from tensorflow.python import data
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorflow\python\eager\context.py:29
#      26 import numpy as np
#      27 import six
# ---> 29 from tensorflow.core.framework import function_pb2
#      30 from tensorflow.core.protobuf import config_pb2
#      31 from tensorflow.core.protobuf import coordination_config_pb2
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorflow\core\framework\function_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import attr_value_pb2 as tensorflow_dot_core_dot_framework_dot_attr__value__pb2
#      17 from tensorflow.core.framework import node_def_pb2 as tensorflow_dot_core_dot_framework_dot_node__def__pb2
#      18 from tensorflow.core.framework import op_def_pb2 as tensorflow_dot_core_dot_framework_dot_op__def__pb2
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorflow\core\framework\attr_value_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorflow\core\framework\tensor_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import resource_handle_pb2 as tensorflow_dot_core_dot_framework_dot_resource__handle__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorflow\core\framework\resource_handle_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      17 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#      20 DESCRIPTOR = _descriptor.FileDescriptor(
#      21   name='tensorflow/core/framework/resource_handle.proto',
#      22   package='tensorflow',
#    (...)
#      26   ,
#      27   dependencies=[tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2.DESCRIPTOR,tensorflow_dot_core_dot_framework_dot_types__pb2.DESCRIPTOR,])
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\tensorflow\core\framework\tensor_shape_pb2.py:36
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='tensorflow/core/framework/tensor_shape.proto',
#      20   package='tensorflow',
#    (...)
#      23   serialized_pb=_b('\n,tensorflow/core/framework/tensor_shape.proto\x12\ntensorflow\"z\n\x10TensorShapeProto\x12-\n\x03\x64im\x18\x02 \x03(\x0b\x32 .tensorflow.TensorShapeProto.Dim\x12\x14\n\x0cunknown_rank\x18\x03 \x01(\x08\x1a!\n\x03\x44im\x12\x0c\n\x04size\x18\x01 \x01(\x03\x12\x0c\n\x04name\x18\x02 \x01(\tB\x87\x01\n\x18org.tensorflow.frameworkB\x11TensorShapeProtosP\x01ZSgithub.com/tensorflow/tensorflow/tensorflow/go/core/framework/tensor_shape_go_proto\xf8\x01\x01\x62\x06proto3')
#      24 )
#      29 _TENSORSHAPEPROTO_DIM = _descriptor.Descriptor(
#      30   name='Dim',
#      31   full_name='tensorflow.TensorShapeProto.Dim',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='size', full_name='tensorflow.TensorShapeProto.Dim.size', index=0,
#      38       number=1, type=3, cpp_type=2, label=1,
#      39       has_default_value=False, default_value=0,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='name', full_name='tensorflow.TensorShapeProto.Dim.name', index=1,
#      45       number=2, type=9, cpp_type=9, label=1,
#      46       has_default_value=False, default_value=_b("").decode('utf-8'),
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50   ],
#      51   extensions=[
#      52   ],
#      53   nested_types=[],
#      54   enum_types=[
#      55   ],
#      56   serialized_options=None,
#      57   is_extendable=False,
#      58   syntax='proto3',
#      59   extension_ranges=[],
#      60   oneofs=[
#      61   ],
#      62   serialized_start=149,
#      63   serialized_end=182,
#      64 )
#      66 _TENSORSHAPEPROTO = _descriptor.Descriptor(
#      67   name='TensorShapeProto',
#      68   full_name='tensorflow.TensorShapeProto',
#    (...)
#     100   serialized_end=182,
#     101 )
#     103 _TENSORSHAPEPROTO_DIM.containing_type = _TENSORSHAPEPROTO
#
# File C:\anaconda3\envs\TensorFlow\lib\site-packages\google\protobuf\descriptor.py:561, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     555 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     556             default_value, message_type, enum_type, containing_type,
#     557             is_extension, extension_scope, options=None,
#     558             serialized_options=None,
#     559             has_default_value=True, containing_oneof=None, json_name=None,
#     560             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 561   _message.Message._CheckCalledFromGeneratedFile()
#     562   if is_extension:
#     563     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates
